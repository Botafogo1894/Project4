# %%
import pandas as pd
chart = pd.read_csv('data.csv')

# %%
chart.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
chart['Preferred Foot'].value_counts()
# Out:
# Right    13948
# Left      4211
# Name: Preferred Foot, dtype: int64

# %%
pd.set_option('display.max_columns', 100)
chart.head(1)
# Out:
#    Unnamed: 0      ID      Name  Age  \
# 0           0  158023  L. Messi   31
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
#
#                                   Flag  Overall  Potential          Club  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona
#
#                                       Club Logo    Value   Wage  Special  \
# 0  https://cdn.sofifa.org/teams/2/light/241.png  €110.5M  €565K     2202
#
#   Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 0           Left                       5.0        4.0          4.0
#
#         Work Rate Body Type Real Face Position  Jersey Number       Joined  \
# 0  Medium/ Medium     Messi       Yes       RF           10.0  Jul 1, 2004
#
#   Loaned From Contract Valid Until Height  Weight    LS    ST    RS    LW  \
# 0         NaN                 2021    5'7  159lbs  88+2  88+2  88+2  92+2
#
#      LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM   RCM    RM  \
# 0  93+2  93+2  93+2  92+2  93+2  93+2  93+2  91+2  84+2  84+2  84+2  91+2
#
#     LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  Crossing  \
# 0  64+2  61+2  61+2  61+2  64+2  59+2  47+2  47+2  47+2  59+2      84.0
#
#    Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  \
# 0       95.0             70.0          90.0     86.0       97.0   93.0
#
#    FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  Agility  \
# 0        94.0         87.0         96.0          91.0         86.0     91.0
#
#    Reactions  Balance  ShotPower  Jumping  Stamina  Strength  LongShots  \
# 0       95.0     95.0       85.0     68.0     72.0      59.0       94.0
#
#    Aggression  Interceptions  Positioning  Vision  Penalties  Composure  \
# 0        48.0           22.0         94.0    94.0       75.0       96.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
#
#    GKPositioning  GKReflexes Release Clause
# 0           14.0         8.0        €226.5M

# %%
chart.shape
# Out:
# (18207, 89)

# %%
final_df = chart.drop(columns = ['Unnamed: 0', 'ID','Photo', 'Nationality', 'Flag','Club','Club Logo','LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
       'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
       'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB',
                                  'Real Face', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 'Release Clause'], axis = 1)

# %%
final_df.shape
# Out:
# (18207, 50)

# %%
final_df.isna().sum()
# Out:
# Name                         0
# Age                          0
# Overall                      0
# Potential                    0
# Value                        0
# Wage                         0
# Special                      0
# Preferred Foot              48
# International Reputation    48
# Weak Foot                   48
# Skill Moves                 48
# Work Rate                   48
# Body Type                   48
# Position                    60
# Height                      48
# Weight                      48
# Crossing                    48
# Finishing                   48
# HeadingAccuracy             48
# ShortPassing                48
# Volleys                     48
# Dribbling                   48
# Curve                       48
# FKAccuracy                  48
# LongPassing                 48
# BallControl                 48
# Acceleration                48
# SprintSpeed                 48
# Agility                     48
# Reactions                   48
# Balance                     48
# ShotPower                   48
# Jumping                     48
# Stamina                     48
# Strength                    48
# LongShots                   48
# Aggression                  48
# Interceptions               48
# Positioning                 48
# Vision                      48
# Penalties                   48
# Composure                   48
# Marking                     48
# StandingTackle              48
# SlidingTackle               48
# GKDiving                    48
# GKHandling                  48
# GKKicking                   48
# GKPositioning               48
# GKReflexes                  48
# dtype: int64

# %%
final_df.dropna(inplace = True)

# %%
final_df.shape
# Out:
# (18147, 50)

# %%
final_df.columns
# Out:
# Index(['Name', 'Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
target = final_df['Value']
final_df.drop(columns=['Value'], inplace=True)
new_table = pd.concat([final_df, target], axis=1)
new_table.head()
# Out:
#                 Name  Age  Overall  Potential   Wage  Special Preferred Foot  \
# 0           L. Messi   31       94         94  €565K     2202           Left
# 1  Cristiano Ronaldo   33       94         94  €405K     2228          Right
# 2          Neymar Jr   26       92         93  €290K     2143          Right
# 3             De Gea   27       91         93  €260K     1471          Right
# 4       K. De Bruyne   27       91         92  €355K     2281          Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 0                       5.0        4.0          4.0  Medium/ Medium
# 1                       5.0        4.0          5.0       High/ Low
# 2                       5.0        5.0          5.0    High/ Medium
# 3                       4.0        3.0          1.0  Medium/ Medium
# 4                       4.0        5.0          4.0      High/ High
#
#     Body Type Position Height  Weight  Crossing  Finishing  HeadingAccuracy  \
# 0       Messi       RF    5'7  159lbs      84.0       95.0             70.0
# 1  C. Ronaldo       ST    6'2  183lbs      84.0       94.0             89.0
# 2      Neymar       LW    5'9  150lbs      79.0       87.0             62.0
# 3        Lean       GK    6'4  168lbs      17.0       13.0             21.0
# 4      Normal      RCM   5'11  154lbs      93.0       82.0             55.0
#
#    ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 0          90.0     86.0       97.0   93.0        94.0         87.0
# 1          81.0     87.0       88.0   81.0        76.0         77.0
# 2          84.0     84.0       96.0   88.0        87.0         78.0
# 3          50.0     13.0       18.0   21.0        19.0         51.0
# 4          92.0     82.0       86.0   85.0        83.0         91.0
#
#    BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 0         96.0          91.0         86.0     91.0       95.0     95.0
# 1         94.0          89.0         91.0     87.0       96.0     70.0
# 2         95.0          94.0         90.0     96.0       94.0     84.0
# 3         42.0          57.0         58.0     60.0       90.0     43.0
# 4         91.0          78.0         76.0     79.0       91.0     77.0
#
#    ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0       85.0     68.0     72.0      59.0       94.0        48.0
# 1       95.0     95.0     88.0      79.0       93.0        63.0
# 2       80.0     61.0     81.0      49.0       82.0        56.0
# 3       31.0     67.0     43.0      64.0       12.0        38.0
# 4       91.0     63.0     90.0      75.0       91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0           22.0         94.0    94.0       75.0       96.0     33.0
# 1           29.0         95.0    82.0       85.0       95.0     28.0
# 2           36.0         89.0    87.0       81.0       94.0     27.0
# 3           30.0         12.0    68.0       40.0       68.0     15.0
# 4           61.0         87.0    94.0       79.0       88.0     68.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            28.0           26.0       6.0        11.0       15.0
# 1            31.0           23.0       7.0        11.0       15.0
# 2            24.0           33.0       9.0         9.0       15.0
# 3            21.0           13.0      90.0        85.0       87.0
# 4            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes    Value
# 0           14.0         8.0  €110.5M
# 1           14.0        11.0     €77M
# 2           15.0        11.0  €118.5M
# 3           88.0        94.0     €72M
# 4           10.0        13.0    €102M

# %%
new_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18147 entries, 0 to 18206
# Data columns (total 50 columns):
# Name                        18147 non-null object
# Age                         18147 non-null int64
# Overall                     18147 non-null int64
# Potential                   18147 non-null int64
# Wage                        18147 non-null object
# Special                     18147 non-null int64
# Preferred Foot              18147 non-null object
# International Reputation    18147 non-null float64
# Weak Foot                   18147 non-null float64
# Skill Moves                 18147 non-null float64
# Work Rate                   18147 non-null object
# Body Type                   18147 non-null object
# Position                    18147 non-null object
# Height                      18147 non-null object
# Weight                      18147 non-null object
# Crossing                    18147 non-null float64
# Finishing                   18147 non-null float64
# HeadingAccuracy             18147 non-null float64
# ShortPassing                18147 non-null float64
# Volleys                     18147 non-null float64
# Dribbling                   18147 non-null float64
# Curve                       18147 non-null float64
# FKAccuracy                  18147 non-null float64
# LongPassing                 18147 non-null float64
# BallControl                 18147 non-null float64
# Acceleration                18147 non-null float64
# SprintSpeed                 18147 non-null float64
# Agility                     18147 non-null float64
# Reactions                   18147 non-null float64
# Balance                     18147 non-null float64
# ShotPower                   18147 non-null float64
# Jumping                     18147 non-null float64
# Stamina                     18147 non-null float64
# Strength                    18147 non-null float64
# LongShots                   18147 non-null float64
# Aggression                  18147 non-null float64
# Interceptions               18147 non-null float64
# Positioning                 18147 non-null float64
# Vision                      18147 non-null float64
# Penalties                   18147 non-null float64
# Composure                   18147 non-null float64
# Marking                     18147 non-null float64
# StandingTackle              18147 non-null float64
# SlidingTackle               18147 non-null float64
# GKDiving                    18147 non-null float64
# GKHandling                  18147 non-null float64
# GKKicking                   18147 non-null float64
# GKPositioning               18147 non-null float64
# GKReflexes                  18147 non-null float64
# Value                       18147 non-null object
# dtypes: float64(37), int64(4), object(9)
# memory usage: 7.1+ MB

# %%
weight_new = list(new_table.Weight)

# %%
clean_weight = [int(item.replace('lbs', "")) for item in weight_new]

# %%
type(clean_weight[0])
# Out:
# int

# %%
new_table["Weight"] = clean_weight

# %%
new_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18147 entries, 0 to 18206
# Data columns (total 50 columns):
# Name                        18147 non-null object
# Age                         18147 non-null int64
# Overall                     18147 non-null int64
# Potential                   18147 non-null int64
# Wage                        18147 non-null object
# Special                     18147 non-null int64
# Preferred Foot              18147 non-null object
# International Reputation    18147 non-null float64
# Weak Foot                   18147 non-null float64
# Skill Moves                 18147 non-null float64
# Work Rate                   18147 non-null object
# Body Type                   18147 non-null object
# Position                    18147 non-null object
# Height                      18147 non-null object
# Weight                      18147 non-null int64
# Crossing                    18147 non-null float64
# Finishing                   18147 non-null float64
# HeadingAccuracy             18147 non-null float64
# ShortPassing                18147 non-null float64
# Volleys                     18147 non-null float64
# Dribbling                   18147 non-null float64
# Curve                       18147 non-null float64
# FKAccuracy                  18147 non-null float64
# LongPassing                 18147 non-null float64
# BallControl                 18147 non-null float64
# Acceleration                18147 non-null float64
# SprintSpeed                 18147 non-null float64
# Agility                     18147 non-null float64
# Reactions                   18147 non-null float64
# Balance                     18147 non-null float64
# ShotPower                   18147 non-null float64
# Jumping                     18147 non-null float64
# Stamina                     18147 non-null float64
# Strength                    18147 non-null float64
# LongShots                   18147 non-null float64
# Aggression                  18147 non-null float64
# Interceptions               18147 non-null float64
# Positioning                 18147 non-null float64
# Vision                      18147 non-null float64
# Penalties                   18147 non-null float64
# Composure                   18147 non-null float64
# Marking                     18147 non-null float64
# StandingTackle              18147 non-null float64
# SlidingTackle               18147 non-null float64
# GKDiving                    18147 non-null float64
# GKHandling                  18147 non-null float64
# GKKicking                   18147 non-null float64
# GKPositioning               18147 non-null float64
# GKReflexes                  18147 non-null float64
# Value                       18147 non-null object
# dtypes: float64(37), int64(5), object(8)
# memory usage: 7.1+ MB

# %%
height_new = list(new_table.Height)

# %%
height_new[:5]
# Out:
# ["5'7", "6'2", "5'9", "6'4", "5'11"]

# %%
def convert_height(height):
    split = height.split("'")
    height = int(split[0])*12 + int(split[1])
    return height

# %%
final_height = [convert_height(item) for item in height_new]

# %%
final_height[:5]
# Out:
# [67, 74, 69, 76, 71]

# %%
new_table["Height"] = final_height

# %%
new_table.drop(['Wage'], axis = 1, inplace = True)

# %%
new_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18147 entries, 0 to 18206
# Data columns (total 49 columns):
# Name                        18147 non-null object
# Age                         18147 non-null int64
# Overall                     18147 non-null int64
# Potential                   18147 non-null int64
# Special                     18147 non-null int64
# Preferred Foot              18147 non-null object
# International Reputation    18147 non-null float64
# Weak Foot                   18147 non-null float64
# Skill Moves                 18147 non-null float64
# Work Rate                   18147 non-null object
# Body Type                   18147 non-null object
# Position                    18147 non-null object
# Height                      18147 non-null int64
# Weight                      18147 non-null int64
# Crossing                    18147 non-null float64
# Finishing                   18147 non-null float64
# HeadingAccuracy             18147 non-null float64
# ShortPassing                18147 non-null float64
# Volleys                     18147 non-null float64
# Dribbling                   18147 non-null float64
# Curve                       18147 non-null float64
# FKAccuracy                  18147 non-null float64
# LongPassing                 18147 non-null float64
# BallControl                 18147 non-null float64
# Acceleration                18147 non-null float64
# SprintSpeed                 18147 non-null float64
# Agility                     18147 non-null float64
# Reactions                   18147 non-null float64
# Balance                     18147 non-null float64
# ShotPower                   18147 non-null float64
# Jumping                     18147 non-null float64
# Stamina                     18147 non-null float64
# Strength                    18147 non-null float64
# LongShots                   18147 non-null float64
# Aggression                  18147 non-null float64
# Interceptions               18147 non-null float64
# Positioning                 18147 non-null float64
# Vision                      18147 non-null float64
# Penalties                   18147 non-null float64
# Composure                   18147 non-null float64
# Marking                     18147 non-null float64
# StandingTackle              18147 non-null float64
# SlidingTackle               18147 non-null float64
# GKDiving                    18147 non-null float64
# GKHandling                  18147 non-null float64
# GKKicking                   18147 non-null float64
# GKPositioning               18147 non-null float64
# GKReflexes                  18147 non-null float64
# Value                       18147 non-null object
# dtypes: float64(37), int64(6), object(6)
# memory usage: 6.9+ MB

# %%
import re
pattern = r'\d+\.?\d?'
matches = re.findall(pattern, "$600.5K")

def convert_value(value):
    pattern = r'\d+\.?\d?'
    if value.endswith("K"):
        matches = float(re.findall(pattern, value)[0])*1000
    else:
        matches = float(re.findall(pattern, value)[0])*1000000
    return matches

# %%
new_values = [convert_value(item) for item in list(new_table.Value)]

# %%
new_values[:5]
# Out:
# [110500000.0, 77000000.0, 118500000.0, 72000000.0, 102000000.0]

# %%
new_table["Value"] = new_values

# %%
new_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18147 entries, 0 to 18206
# Data columns (total 49 columns):
# Name                        18147 non-null object
# Age                         18147 non-null int64
# Overall                     18147 non-null int64
# Potential                   18147 non-null int64
# Special                     18147 non-null int64
# Preferred Foot              18147 non-null object
# International Reputation    18147 non-null float64
# Weak Foot                   18147 non-null float64
# Skill Moves                 18147 non-null float64
# Work Rate                   18147 non-null object
# Body Type                   18147 non-null object
# Position                    18147 non-null object
# Height                      18147 non-null int64
# Weight                      18147 non-null int64
# Crossing                    18147 non-null float64
# Finishing                   18147 non-null float64
# HeadingAccuracy             18147 non-null float64
# ShortPassing                18147 non-null float64
# Volleys                     18147 non-null float64
# Dribbling                   18147 non-null float64
# Curve                       18147 non-null float64
# FKAccuracy                  18147 non-null float64
# LongPassing                 18147 non-null float64
# BallControl                 18147 non-null float64
# Acceleration                18147 non-null float64
# SprintSpeed                 18147 non-null float64
# Agility                     18147 non-null float64
# Reactions                   18147 non-null float64
# Balance                     18147 non-null float64
# ShotPower                   18147 non-null float64
# Jumping                     18147 non-null float64
# Stamina                     18147 non-null float64
# Strength                    18147 non-null float64
# LongShots                   18147 non-null float64
# Aggression                  18147 non-null float64
# Interceptions               18147 non-null float64
# Positioning                 18147 non-null float64
# Vision                      18147 non-null float64
# Penalties                   18147 non-null float64
# Composure                   18147 non-null float64
# Marking                     18147 non-null float64
# StandingTackle              18147 non-null float64
# SlidingTackle               18147 non-null float64
# GKDiving                    18147 non-null float64
# GKHandling                  18147 non-null float64
# GKKicking                   18147 non-null float64
# GKPositioning               18147 non-null float64
# GKReflexes                  18147 non-null float64
# Value                       18147 non-null float64
# dtypes: float64(38), int64(6), object(5)
# memory usage: 6.9+ MB

# %%
new_table['Body Type'].value_counts()
# Out:
# Normal                 10588
# Lean                    6412
# Stocky                  1140
# Akinfenwa                  1
# PLAYER_BODY_TYPE_25        1
# Shaqiri                    1
# C. Ronaldo                 1
# Neymar                     1
# Messi                      1
# Courtois                   1
# Name: Body Type, dtype: int64

# %%
list_body = list(new_table['Body Type'])
names = ['Akinfenwa', 'PLAYER_BODY_TYPE_25', 'Shaqiri', 'Messi', 'Neymar', 'Courtois', 'C. Ronaldo']

# %%
for idx, item in enumerate(list_body):
    if item in names:
        list_body[idx] = "Lean"

# %%
set(list_body)
# Out:
# {'Lean', 'Normal', 'Stocky'}

# %%
list_body[:5]
# Out:
# ['Lean', 'Lean', 'Lean', 'Lean', 'Normal']

# %%
new_table['Body Type'] = list_body

# %%
new_table['Body Type'].value_counts()
# Out:
# Normal    10588
# Lean       6419
# Stocky     1140
# Name: Body Type, dtype: int64

# %%
new_table.head()
# Out:
#                 Name  Age  Overall  Potential  Special Preferred Foot  \
# 0           L. Messi   31       94         94     2202           Left
# 1  Cristiano Ronaldo   33       94         94     2228          Right
# 2          Neymar Jr   26       92         93     2143          Right
# 3             De Gea   27       91         93     1471          Right
# 4       K. De Bruyne   27       91         92     2281          Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate Body Type  \
# 0                       5.0        4.0          4.0  Medium/ Medium      Lean
# 1                       5.0        4.0          5.0       High/ Low      Lean
# 2                       5.0        5.0          5.0    High/ Medium      Lean
# 3                       4.0        3.0          1.0  Medium/ Medium      Lean
# 4                       4.0        5.0          4.0      High/ High    Normal
#
#   Position  Height  Weight  Crossing  Finishing  HeadingAccuracy  \
# 0       RF      67     159      84.0       95.0             70.0
# 1       ST      74     183      84.0       94.0             89.0
# 2       LW      69     150      79.0       87.0             62.0
# 3       GK      76     168      17.0       13.0             21.0
# 4      RCM      71     154      93.0       82.0             55.0
#
#    ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 0          90.0     86.0       97.0   93.0        94.0         87.0
# 1          81.0     87.0       88.0   81.0        76.0         77.0
# 2          84.0     84.0       96.0   88.0        87.0         78.0
# 3          50.0     13.0       18.0   21.0        19.0         51.0
# 4          92.0     82.0       86.0   85.0        83.0         91.0
#
#    BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 0         96.0          91.0         86.0     91.0       95.0     95.0
# 1         94.0          89.0         91.0     87.0       96.0     70.0
# 2         95.0          94.0         90.0     96.0       94.0     84.0
# 3         42.0          57.0         58.0     60.0       90.0     43.0
# 4         91.0          78.0         76.0     79.0       91.0     77.0
#
#    ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0       85.0     68.0     72.0      59.0       94.0        48.0
# 1       95.0     95.0     88.0      79.0       93.0        63.0
# 2       80.0     61.0     81.0      49.0       82.0        56.0
# 3       31.0     67.0     43.0      64.0       12.0        38.0
# 4       91.0     63.0     90.0      75.0       91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0           22.0         94.0    94.0       75.0       96.0     33.0
# 1           29.0         95.0    82.0       85.0       95.0     28.0
# 2           36.0         89.0    87.0       81.0       94.0     27.0
# 3           30.0         12.0    68.0       40.0       68.0     15.0
# 4           61.0         87.0    94.0       79.0       88.0     68.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            28.0           26.0       6.0        11.0       15.0
# 1            31.0           23.0       7.0        11.0       15.0
# 2            24.0           33.0       9.0         9.0       15.0
# 3            21.0           13.0      90.0        85.0       87.0
# 4            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes        Value
# 0           14.0         8.0  110500000.0
# 1           14.0        11.0   77000000.0
# 2           15.0        11.0  118500000.0
# 3           88.0        94.0   72000000.0
# 4           10.0        13.0  102000000.0

# %%
test = new_table.set_index("Name")

# %%
test.head()
# Out:
#                    Age  Overall  Potential  Special Preferred Foot  \
# Name
# L. Messi            31       94         94     2202           Left
# Cristiano Ronaldo   33       94         94     2228          Right
# Neymar Jr           26       92         93     2143          Right
# De Gea              27       91         93     1471          Right
# K. De Bruyne        27       91         92     2281          Right
#
#                    International Reputation  Weak Foot  Skill Moves  \
# Name
# L. Messi                                5.0        4.0          4.0
# Cristiano Ronaldo                       5.0        4.0          5.0
# Neymar Jr                               5.0        5.0          5.0
# De Gea                                  4.0        3.0          1.0
# K. De Bruyne                            4.0        5.0          4.0
#
#                         Work Rate Body Type Position  Height  Weight  \
# Name
# L. Messi           Medium/ Medium      Lean       RF      67     159
# Cristiano Ronaldo       High/ Low      Lean       ST      74     183
# Neymar Jr            High/ Medium      Lean       LW      69     150
# De Gea             Medium/ Medium      Lean       GK      76     168
# K. De Bruyne           High/ High    Normal      RCM      71     154
#
#                    Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Name
# L. Messi               84.0       95.0             70.0          90.0
# Cristiano Ronaldo      84.0       94.0             89.0          81.0
# Neymar Jr              79.0       87.0             62.0          84.0
# De Gea                 17.0       13.0             21.0          50.0
# K. De Bruyne           93.0       82.0             55.0          92.0
#
#                    Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# Name
# L. Messi              86.0       97.0   93.0        94.0         87.0
# Cristiano Ronaldo     87.0       88.0   81.0        76.0         77.0
# Neymar Jr             84.0       96.0   88.0        87.0         78.0
# De Gea                13.0       18.0   21.0        19.0         51.0
# K. De Bruyne          82.0       86.0   85.0        83.0         91.0
#
#                    BallControl  Acceleration  SprintSpeed  Agility  Reactions  \
# Name
# L. Messi                  96.0          91.0         86.0     91.0       95.0
# Cristiano Ronaldo         94.0          89.0         91.0     87.0       96.0
# Neymar Jr                 95.0          94.0         90.0     96.0       94.0
# De Gea                    42.0          57.0         58.0     60.0       90.0
# K. De Bruyne              91.0          78.0         76.0     79.0       91.0
#
#                    Balance  ShotPower  Jumping  Stamina  Strength  LongShots  \
# Name
# L. Messi              95.0       85.0     68.0     72.0      59.0       94.0
# Cristiano Ronaldo     70.0       95.0     95.0     88.0      79.0       93.0
# Neymar Jr             84.0       80.0     61.0     81.0      49.0       82.0
# De Gea                43.0       31.0     67.0     43.0      64.0       12.0
# K. De Bruyne          77.0       91.0     63.0     90.0      75.0       91.0
#
#                    Aggression  Interceptions  Positioning  Vision  Penalties  \
# Name
# L. Messi                 48.0           22.0         94.0    94.0       75.0
# Cristiano Ronaldo        63.0           29.0         95.0    82.0       85.0
# Neymar Jr                56.0           36.0         89.0    87.0       81.0
# De Gea                   38.0           30.0         12.0    68.0       40.0
# K. De Bruyne             76.0           61.0         87.0    94.0       79.0
#
#                    Composure  Marking  StandingTackle  SlidingTackle  \
# Name
# L. Messi                96.0     33.0            28.0           26.0
# Cristiano Ronaldo       95.0     28.0            31.0           23.0
# Neymar Jr               94.0     27.0            24.0           33.0
# De Gea                  68.0     15.0            21.0           13.0
# K. De Bruyne            88.0     68.0            58.0           51.0
#
#                    GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# Name
# L. Messi                6.0        11.0       15.0           14.0         8.0
# Cristiano Ronaldo       7.0        11.0       15.0           14.0        11.0
# Neymar Jr               9.0         9.0       15.0           15.0        11.0
# De Gea                 90.0        85.0       87.0           88.0        94.0
# K. De Bruyne           15.0        13.0        5.0           10.0        13.0
#
#                          Value
# Name
# L. Messi           110500000.0
# Cristiano Ronaldo   77000000.0
# Neymar Jr          118500000.0
# De Gea              72000000.0
# K. De Bruyne       102000000.0

# %%
test.shape
# Out:
# (18147, 48)

# %%
plot_table = test[:100]
plot_table.head()
# Out:
#                    Age  Overall  Potential  Special Preferred Foot  \
# Name
# L. Messi            31       94         94     2202           Left
# Cristiano Ronaldo   33       94         94     2228          Right
# Neymar Jr           26       92         93     2143          Right
# De Gea              27       91         93     1471          Right
# K. De Bruyne        27       91         92     2281          Right
#
#                    International Reputation  Weak Foot  Skill Moves  \
# Name
# L. Messi                                5.0        4.0          4.0
# Cristiano Ronaldo                       5.0        4.0          5.0
# Neymar Jr                               5.0        5.0          5.0
# De Gea                                  4.0        3.0          1.0
# K. De Bruyne                            4.0        5.0          4.0
#
#                         Work Rate Body Type Position  Height  Weight  \
# Name
# L. Messi           Medium/ Medium      Lean       RF      67     159
# Cristiano Ronaldo       High/ Low      Lean       ST      74     183
# Neymar Jr            High/ Medium      Lean       LW      69     150
# De Gea             Medium/ Medium      Lean       GK      76     168
# K. De Bruyne           High/ High    Normal      RCM      71     154
#
#                    Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Name
# L. Messi               84.0       95.0             70.0          90.0
# Cristiano Ronaldo      84.0       94.0             89.0          81.0
# Neymar Jr              79.0       87.0             62.0          84.0
# De Gea                 17.0       13.0             21.0          50.0
# K. De Bruyne           93.0       82.0             55.0          92.0
#
#                    Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# Name
# L. Messi              86.0       97.0   93.0        94.0         87.0
# Cristiano Ronaldo     87.0       88.0   81.0        76.0         77.0
# Neymar Jr             84.0       96.0   88.0        87.0         78.0
# De Gea                13.0       18.0   21.0        19.0         51.0
# K. De Bruyne          82.0       86.0   85.0        83.0         91.0
#
#                    BallControl  Acceleration  SprintSpeed  Agility  Reactions  \
# Name
# L. Messi                  96.0          91.0         86.0     91.0       95.0
# Cristiano Ronaldo         94.0          89.0         91.0     87.0       96.0
# Neymar Jr                 95.0          94.0         90.0     96.0       94.0
# De Gea                    42.0          57.0         58.0     60.0       90.0
# K. De Bruyne              91.0          78.0         76.0     79.0       91.0
#
#                    Balance  ShotPower  Jumping  Stamina  Strength  LongShots  \
# Name
# L. Messi              95.0       85.0     68.0     72.0      59.0       94.0
# Cristiano Ronaldo     70.0       95.0     95.0     88.0      79.0       93.0
# Neymar Jr             84.0       80.0     61.0     81.0      49.0       82.0
# De Gea                43.0       31.0     67.0     43.0      64.0       12.0
# K. De Bruyne          77.0       91.0     63.0     90.0      75.0       91.0
#
#                    Aggression  Interceptions  Positioning  Vision  Penalties  \
# Name
# L. Messi                 48.0           22.0         94.0    94.0       75.0
# Cristiano Ronaldo        63.0           29.0         95.0    82.0       85.0
# Neymar Jr                56.0           36.0         89.0    87.0       81.0
# De Gea                   38.0           30.0         12.0    68.0       40.0
# K. De Bruyne             76.0           61.0         87.0    94.0       79.0
#
#                    Composure  Marking  StandingTackle  SlidingTackle  \
# Name
# L. Messi                96.0     33.0            28.0           26.0
# Cristiano Ronaldo       95.0     28.0            31.0           23.0
# Neymar Jr               94.0     27.0            24.0           33.0
# De Gea                  68.0     15.0            21.0           13.0
# K. De Bruyne            88.0     68.0            58.0           51.0
#
#                    GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# Name
# L. Messi                6.0        11.0       15.0           14.0         8.0
# Cristiano Ronaldo       7.0        11.0       15.0           14.0        11.0
# Neymar Jr               9.0         9.0       15.0           15.0        11.0
# De Gea                 90.0        85.0       87.0           88.0        94.0
# K. De Bruyne           15.0        13.0        5.0           10.0        13.0
#
#                          Value
# Name
# L. Messi           110500000.0
# Cristiano Ronaldo   77000000.0
# Neymar Jr          118500000.0
# De Gea              72000000.0
# K. De Bruyne       102000000.0

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline



# variables = list(plot_table.columns)[:14]
# sns.pairplot(plot_table, x_vars=variables[:7], y_vars=plot_table.Value)
# sns.pairplot(plot_table, x_vars=variables[7:14], y_vars=plot_table.Value)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (8,6))
plt.title("Regular Variables Correlation Heatmap", fontsize = 18, color = "#F97E77")
sns.heatmap(test.corr(), center = 0)

# %%
dummies_df = test[["Preferred Foot", 'Body Type', 'Work Rate', 'Position' ]]

# %%
target = test.Value
target.shape
# Out:
# (18147,)

# %%
test.drop(columns = ["Preferred Foot", 'Body Type', 'Work Rate', 'Position', 'Value' ], inplace = True)

# %%
test.head()
# Out:
#                    Age  Overall  Potential  Special  International Reputation  \
# Name
# L. Messi            31       94         94     2202                       5.0
# Cristiano Ronaldo   33       94         94     2228                       5.0
# Neymar Jr           26       92         93     2143                       5.0
# De Gea              27       91         93     1471                       4.0
# K. De Bruyne        27       91         92     2281                       4.0
#
#                    Weak Foot  Skill Moves  Height  Weight  Crossing  \
# Name
# L. Messi                 4.0          4.0      67     159      84.0
# Cristiano Ronaldo        4.0          5.0      74     183      84.0
# Neymar Jr                5.0          5.0      69     150      79.0
# De Gea                   3.0          1.0      76     168      17.0
# K. De Bruyne             5.0          4.0      71     154      93.0
#
#                    Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# Name
# L. Messi                95.0             70.0          90.0     86.0
# Cristiano Ronaldo       94.0             89.0          81.0     87.0
# Neymar Jr               87.0             62.0          84.0     84.0
# De Gea                  13.0             21.0          50.0     13.0
# K. De Bruyne            82.0             55.0          92.0     82.0
#
#                    Dribbling  Curve  FKAccuracy  LongPassing  BallControl  \
# Name
# L. Messi                97.0   93.0        94.0         87.0         96.0
# Cristiano Ronaldo       88.0   81.0        76.0         77.0         94.0
# Neymar Jr               96.0   88.0        87.0         78.0         95.0
# De Gea                  18.0   21.0        19.0         51.0         42.0
# K. De Bruyne            86.0   85.0        83.0         91.0         91.0
#
#                    Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# Name
# L. Messi                   91.0         86.0     91.0       95.0     95.0
# Cristiano Ronaldo          89.0         91.0     87.0       96.0     70.0
# Neymar Jr                  94.0         90.0     96.0       94.0     84.0
# De Gea                     57.0         58.0     60.0       90.0     43.0
# K. De Bruyne               78.0         76.0     79.0       91.0     77.0
#
#                    ShotPower  Jumping  Stamina  Strength  LongShots  \
# Name
# L. Messi                85.0     68.0     72.0      59.0       94.0
# Cristiano Ronaldo       95.0     95.0     88.0      79.0       93.0
# Neymar Jr               80.0     61.0     81.0      49.0       82.0
# De Gea                  31.0     67.0     43.0      64.0       12.0
# K. De Bruyne            91.0     63.0     90.0      75.0       91.0
#
#                    Aggression  Interceptions  Positioning  Vision  Penalties  \
# Name
# L. Messi                 48.0           22.0         94.0    94.0       75.0
# Cristiano Ronaldo        63.0           29.0         95.0    82.0       85.0
# Neymar Jr                56.0           36.0         89.0    87.0       81.0
# De Gea                   38.0           30.0         12.0    68.0       40.0
# K. De Bruyne             76.0           61.0         87.0    94.0       79.0
#
#                    Composure  Marking  StandingTackle  SlidingTackle  \
# Name
# L. Messi                96.0     33.0            28.0           26.0
# Cristiano Ronaldo       95.0     28.0            31.0           23.0
# Neymar Jr               94.0     27.0            24.0           33.0
# De Gea                  68.0     15.0            21.0           13.0
# K. De Bruyne            88.0     68.0            58.0           51.0
#
#                    GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes
# Name
# L. Messi                6.0        11.0       15.0           14.0         8.0
# Cristiano Ronaldo       7.0        11.0       15.0           14.0        11.0
# Neymar Jr               9.0         9.0       15.0           15.0        11.0
# De Gea                 90.0        85.0       87.0           88.0        94.0
# K. De Bruyne           15.0        13.0        5.0           10.0        13.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(test), columns = test.columns, index = test.index)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
scaled_df.shape
# Out:
# (18147, 43)

# %%
dummies_final = pd.get_dummies(dummies_df)
# test_table = pd.concat([test_table, dummies], axis=1)
# test_table.drop(columns=['Religious', ], inplace=True)
# test_table.drop(columns=['Rel_Medium'], inplace=True)

# %%
dummies_final.drop(columns = ["Preferred Foot_Right", "Position_GK", "Body Type_Stocky", "Work Rate_Low/ High"], inplace = True)

# %%
dummies_final.shape
# Out:
# (18147, 37)

# %%
final_df = pd.concat([scaled_df, dummies_final], axis = 1)

# %%
final_df.head()
# Out:
#                         Age   Overall  Potential   Special  \
# Name
# L. Messi           1.258950  4.013533   3.697895  2.213456
# Cristiano Ronaldo  1.687246  4.013533   3.697895  2.308738
# Neymar Jr          0.188210  3.724228   3.534819  1.997240
# De Gea             0.402358  3.579576   3.534819 -0.465424
# K. De Bruyne       0.402358  3.579576   3.371743  2.502966
#
#                    International Reputation  Weak Foot  Skill Moves    Height  \
# Name
# L. Messi                           9.861240   1.594064     2.166613 -1.646241
# Cristiano Ronaldo                  9.861240   1.594064     3.488921  0.995602
# Neymar Jr                          9.861240   3.108115     3.488921 -0.891429
# De Gea                             7.324066   0.080012    -1.800313  1.750414
# K. De Bruyne                       7.324066   3.108115     2.166613 -0.136617
#
#                      Weight  Crossing  Finishing  HeadingAccuracy  \
# Name
# L. Messi          -0.447829  1.865719   2.532391         1.018293
# Cristiano Ronaldo  1.091328  1.865719   2.481180         2.111424
# Neymar Jr         -1.025012  1.593443   2.122700         0.558028
# De Gea             0.129355 -1.782774  -1.666942        -1.800833
# K. De Bruyne      -0.768486  2.355815   1.866643         0.155296
#
#                    ShortPassing   Volleys  Dribbling     Curve  FKAccuracy  \
# Name
# L. Messi               2.130190  2.434969   2.201010  2.491028    2.925359
# Cristiano Ronaldo      1.517765  2.491481   1.725114  1.838695    1.895584
# Neymar Jr              1.721906  2.321945   2.148132  2.219223    2.524891
# De Gea                -0.591700 -1.690394  -1.976298 -1.422972   -1.365369
# K. De Bruyne           2.266284  2.208922   1.619359  2.056139    2.296052
#
#                    LongPassing  BallControl  Acceleration  SprintSpeed  \
# Name
# L. Messi              2.236808     2.255005      1.767403     1.451998
# Cristiano Ronaldo     1.584271     2.135138      1.633444     1.793263
# Neymar Jr             1.649524     2.195072      1.968342     1.725010
# De Gea               -0.112327    -0.981399     -0.509905    -0.459086
# K. De Bruyne          2.497823     1.955338      0.896668     0.769468
#
#                     Agility  Reactions   Balance  ShotPower   Jumping  \
# Name
# L. Messi           1.861977   3.680120  2.195558   1.713647  0.246064
# Cristiano Ronaldo  1.591132   3.791098  0.426984   2.293859  2.529941
# Neymar Jr          2.200535   3.569142  1.417385   1.423540 -0.346053
# De Gea            -0.237078   3.125231 -1.483076  -1.419502  0.161476
# K. De Bruyne       1.049440   3.236208  0.922185   2.061774 -0.176877
#
#                     Stamina  Strength  LongShots  Aggression  Interceptions  \
# Name
# L. Messi           0.552243 -0.503390   2.434084   -0.453532      -1.193549
# Cristiano Ronaldo  1.558789  1.089964   2.382170    0.410222      -0.855334
# Neymar Jr          1.118425 -1.300067   1.811115    0.007136      -0.517119
# De Gea            -1.272122 -0.105051  -1.822867   -1.029368      -0.807018
# K. De Bruyne       1.684607  0.771294   2.278342    1.158808       0.690792
#
#                    Positioning    Vision  Penalties  Composure   Marking  \
# Name
# L. Messi              2.254888  2.869478   1.684657   3.265669 -0.717896
# Cristiano Ronaldo     2.306091  2.021194   2.321491   3.178232 -0.969153
# Neymar Jr             1.998870  2.374645   2.066757   3.090795 -1.019405
# De Gea               -1.943796  1.031529  -0.544262   0.817436 -1.622423
# K. De Bruyne          1.896464  2.869478   1.939390   2.566174  1.040907
#
#                    StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# Name
# L. Messi                -0.909470      -0.923850 -0.599889   -0.318983
# Cristiano Ronaldo       -0.770985      -1.064778 -0.543386   -0.318983
# Neymar Jr               -1.094116      -0.595016 -0.430379   -0.437259
# De Gea                  -1.232601      -1.534540  4.146377    4.057254
# K. De Bruyne             0.475378       0.250555 -0.091360   -0.200706
#
#                    GKKicking  GKPositioning  GKReflexes  Preferred Foot_Left  \
# Name
# L. Messi           -0.074713      -0.140266   -0.485159                    1
# Cristiano Ronaldo  -0.074713      -0.140266   -0.318094                    0
# Neymar Jr          -0.074713      -0.081569   -0.318094                    0
# De Gea              4.287959       4.203333    4.304052                    0
# K. De Bruyne       -0.680640      -0.375055   -0.206717                    0
#
#                    Body Type_Lean  Body Type_Normal  Work Rate_High/ High  \
# Name
# L. Messi                        1                 0                     0
# Cristiano Ronaldo               1                 0                     0
# Neymar Jr                       1                 0                     0
# De Gea                          1                 0                     0
# K. De Bruyne                    0                 1                     1
#
#                    Work Rate_High/ Low  Work Rate_High/ Medium  \
# Name
# L. Messi                             0                       0
# Cristiano Ronaldo                    1                       0
# Neymar Jr                            0                       1
# De Gea                               0                       0
# K. De Bruyne                         0                       0
#
#                    Work Rate_Low/ Low  Work Rate_Low/ Medium  \
# Name
# L. Messi                            0                      0
# Cristiano Ronaldo                   0                      0
# Neymar Jr                           0                      0
# De Gea                              0                      0
# K. De Bruyne                        0                      0
#
#                    Work Rate_Medium/ High  Work Rate_Medium/ Low  \
# Name
# L. Messi                                0                      0
# Cristiano Ronaldo                       0                      0
# Neymar Jr                               0                      0
# De Gea                                  0                      0
# K. De Bruyne                            0                      0
#
#                    Work Rate_Medium/ Medium  Position_CAM  Position_CB  \
# Name
# L. Messi                                  1             0            0
# Cristiano Ronaldo                         0             0            0
# Neymar Jr                                 0             0            0
# De Gea                                    1             0            0
# K. De Bruyne                              0             0            0
#
#                    Position_CDM  Position_CF  Position_CM  Position_LAM  \
# Name
# L. Messi                      0            0            0             0
# Cristiano Ronaldo             0            0            0             0
# Neymar Jr                     0            0            0             0
# De Gea                        0            0            0             0
# K. De Bruyne                  0            0            0             0
#
#                    Position_LB  Position_LCB  Position_LCM  Position_LDM  \
# Name
# L. Messi                     0             0             0             0
# Cristiano Ronaldo            0             0             0             0
# Neymar Jr                    0             0             0             0
# De Gea                       0             0             0             0
# K. De Bruyne                 0             0             0             0
#
#                    Position_LF  Position_LM  Position_LS  Position_LW  \
# Name
# L. Messi                     0            0            0            0
# Cristiano Ronaldo            0            0            0            0
# Neymar Jr                    0            0            0            1
# De Gea                       0            0            0            0
# K. De Bruyne                 0            0            0            0
#
#                    Position_LWB  Position_RAM  Position_RB  Position_RCB  \
# Name
# L. Messi                      0             0            0             0
# Cristiano Ronaldo             0             0            0             0
# Neymar Jr                     0             0            0             0
# De Gea                        0             0            0             0
# K. De Bruyne                  0             0            0             0
#
#                    Position_RCM  Position_RDM  Position_RF  Position_RM  \
# Name
# L. Messi                      0             0            1            0
# Cristiano Ronaldo             0             0            0            0
# Neymar Jr                     0             0            0            0
# De Gea                        0             0            0            0
# K. De Bruyne                  1             0            0            0
#
#                    Position_RS  Position_RW  Position_RWB  Position_ST
# Name
# L. Messi                     0            0             0            0
# Cristiano Ronaldo            0            0             0            1
# Neymar Jr                    0            0             0            0
# De Gea                       0            0             0            0
# K. De Bruyne                 0            0             0            0

# %%
final_df.shape
# Out:
# (18147, 80)

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.feature_selection import RFE
from sklearn.model_selection import KFold

import numpy as np 

X = final_df
y = target

def MSE_test(X, y, random_state = 18):
    poly_RSME = []
    for i in range(1, len(X.columns)):
        linreg = Ridge()
        selector = RFE(linreg, n_features_to_select = i)
        selector = selector.fit(X, y)
        selected_columns = X.columns[selector.support_]
        selected_var = [column for column in selected_columns]
        X_train, X_test, y_train, y_test = train_test_split(X[selected_columns], y, random_state = random_state,  test_size=.20)
        
        crossvalidation = KFold(n_splits=5, shuffle=True, random_state=1)
        cv_10_results = np.mean(cross_val_score(linreg, X_train, y_train, cv=crossvalidation, scoring='neg_mean_squared_error'))
        cv_10_results= np.sqrt(abs(cv_10_results))
        poly_RSME.append(dict(variables = selected_var, RMSE = cv_10_results, nu_var = len( selected_var)))
    return poly_RSME

poly_model_list = MSE_test(X, y)

def find_best_model(model_list):
    sorted_mse = sorted(model_list, key=lambda k: k['RMSE'])
    return sorted_mse[0]
    
find_best_model(poly_model_list)
# Out:
# {'variables': ['Age',
#   'Overall',
#   'Potential',
#   'Special',
#   'International Reputation',
#   'Finishing',
#   'Volleys',
#   'FKAccuracy',
#   'LongPassing',
#   'BallControl',
#   'Acceleration',
#   'SprintSpeed',
#   'Reactions',
#   'Balance',
#   'ShotPower',
#   'Stamina',
#   'Strength',
#   'Positioning',
#   'Vision',
#   'Marking',
#   'StandingTackle',
#   'GKDiving',
#   'GKKicking',
#   'GKPositioning',
#   'GKReflexes',
#   'Work Rate_High/ High',
#   'Work Rate_High/ Low',
#   'Work Rate_High/ Medium',
#   'Work Rate_Low/ Low',
#   'Work Rate_Low/ Medium',
#   'Work Rate_Medium/ High',
#   'Work Rate_Medium/ Low',
#   'Work Rate_Medium/ Medium',
#   'Position_CAM',
#   'Position_CB',
#   'Position_CDM',
#   'Position_CF',
#   'Position_CM',
#   'Position_LAM',
#   'Position_LB',
#   'Position_LCB',
#   'Position_LCM',
#   'Position_LDM',
#   'Position_LF',
#   'Position_LM',
#   'Position_LS',
#   'Position_LW',
#   'Position_LWB',
#   'Position_RAM',
#   'Position_RB',
#   'Position_RCB',
#   'Position_RCM',
#   'Position_RDM',
#   'Position_RF',
#   'Position_RM',
#   'Position_RS',
#   'Position_RW',
#   'Position_RWB',
#   'Position_ST'],
#  'RMSE': 3549952.923345717,
#  'nu_var': 59}

# %%
import matplotlib.patches as mpatches

min_rmse = find_best_model(poly_model_list)['RMSE']
min_var = find_best_model(poly_model_list)['nu_var']
x_val = [item['nu_var'] for item in poly_model_list[:55]]
y_val = [item['RMSE'] for item in poly_model_list[:55]]
plt.figure(figsize = (9,7))
plt.title("Minimizing RMSE Function", fontsize = 25, color = "#073A5A")
plt.plot(x_val, y_val)
plt.xlabel("Number of Independent Variables", fontsize = 18, color = "#073A5A")
plt.ylabel("RMSE", fontsize = 18, color = "#073A5A")

rmse_patch = mpatches.Patch(color='blue', label="RMSE = {}".format(round(min_rmse, 3)))
vars_patch = mpatches.Patch(color='green', label="Variables Chosen = {}".format(min_var))
plt.legend(handles=[rmse_patch, vars_patch])

# %%
selected_variables = find_best_model(poly_model_list)['variables']
X_train, X_test, y_train, y_test = train_test_split(X[selected_variables], y, random_state = 18,  test_size=.20)
linreg = Ridge()
linreg.fit(X_train[selected_variables], y_train)
yhat = linreg.predict(X_test[selected_variables])

RMSE = np.sqrt(mean_squared_error(y_test, yhat))
z_score = RMSE/np.std(y_test)
R_squared = linreg.score(X_test, y_test)
print("RMSE = {}, z_score = {}, R_squared = {}".format(RMSE, z_score, R_squared))
# Out:
# RMSE = 3170891.3310399954, z_score = 0.617909762394871, R_squared = 0.6181875255371141

# %%
import matplotlib.patches as mpatches

def bias(y, y_hat):
    return np.mean(y_hat - y)

def variance(y_hat):
    return np.mean([yi**2 for yi in y_hat]) - np.mean(y_hat)**2

selected_columns = find_best_model(poly_model_list)['variables']
X_train, X_test, y_train, y_test = train_test_split(X[selected_columns], y, random_state = 12,  test_size=.20)

reg = Ridge().fit(X_train, y_train)

y_hat_train = reg.predict(X_train)
y_hat_test = reg.predict(X_test)
bias_train = bias(y_train, y_hat_train)
bias_test = bias(y_test, y_hat_test)
var_train = variance(y_hat_train)
var_test = variance(y_hat_test)

RMSE_train = np.sqrt(mean_squared_error(y_train, y_hat_train))
z_score_train = RMSE/np.std(y_train)
R_squared_train = linreg.score(X_train, y_train)

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize = (15,5))

ax1.set_title("Polynomial y_hat_train vs y_train", fontsize = 16)
ax1.set_xlabel("y_train",fontsize = 14, color = "#073A5A")
ax1.set_ylabel("y_hat_train",fontsize = 14, color = "#073A5A")
ax1.scatter(y_train, y_hat_train, color = "blue", label='Actual Data')
ax1.plot(y_train, y_train, color = "red", label='Model')

R2_patch = mpatches.Patch(color='#aaff80', label="R_squared_train = {}".format(round(R_squared_train, 3)))
RMSE_patch = mpatches.Patch(color='#ffd480', label="RMSE_train = {}".format(round(RMSE_train, 3)))
z_patch = mpatches.Patch(color='#00cccc', label="z_score_train = {}".format(round(z_score_train, 3)))
Bias_patch = mpatches.Patch(color='#670000', label="Bias_train = {}".format(round(bias_train, 20)))
Variance_patch = mpatches.Patch(color='#7A9A01', label="Var_train = {}".format(round(var_train, 3)))

ax1.legend(handles=[R2_patch, RMSE_patch, z_patch, Bias_patch, Variance_patch])

ax2.set_title("Polynomial y_hat_test vs y_test", fontsize = 16)
ax2.set_xlabel("y_test", fontsize = 14, color = "#073A5A")
ax2.set_ylabel("y_hat_test", fontsize = 14, color = "#073A5A")
ax2.scatter(y_test, y_hat_test, color = "blue")
ax2.plot(y_test, y_test, color = "red")

R2_patch = mpatches.Patch(color='#aaff80', label="R_squared = {}".format(round(R_squared, 3)))
RMSE_patch = mpatches.Patch(color='#ffd480', label="RMSE = {}".format(round(RMSE, 3)))
z_patch = mpatches.Patch(color='#00cccc', label="z_score = {}".format(round(z_score, 3)))
Bias_patch = mpatches.Patch(color='#670000', label="Bias = {}".format(round(bias_test, 3)))
Variance_patch = mpatches.Patch(color='#7A9A01', label="Var = {}".format(round(var_test, 3)))

ax2.legend(handles=[R2_patch, RMSE_patch, z_patch,  Bias_patch, Variance_patch], loc = "upper left")

# %%
test = list(zip(linreg.coef_, selected_variables))
combined = [str(round(item[0], 2)) + "*" +item[1] for item in test]
one_string = "  +  ".join(combined)
equation = one_string.replace("+  -", "-  ")

# %%
coefs = [item[0] for item in test]
varias = [item[1] for item in test]
plt.figure(figsize = (12,8))
plt.title("Independent Variables Chart", fontsize = 30, color = "#535355")
plt.xlabel("Independent Variable", fontsize = 18, color = "#050594")
plt.ylabel("Coefficient Size", fontsize = 18, color = "#050594")
plt.xticks(rotation=90)
plt.bar(varias, coefs)
# Out:
# <BarContainer object of 59 artists>

# %% [markdown]
# ## Random Forest

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 18,  test_size=.20)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# y_train_new = [int(item) for item in y_train]
forest = RandomForestClassifier(n_estimators=40, max_depth=10, min_samples_leaf = 3)
forest.fit(X_train, y_train.astype(int))
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=3, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
forest.score(X_test, y_test.astype(int))
# Out:
# 0.14325068870523416

# %%
feat_importances = pd.Series(forest.feature_importances_, index=X.columns)
feat_importances.nlargest(20).plot(kind='barh')

# %% [markdown]
# ### XGboost

# %%
# import xgboost as xgb

# clf = xgb.XGBClassifier()
# clf.fit(X_train, y_train)
